# %% [markdown]
# # AIN 214 PA3 on Data Prepocessing and Regression

# %% [markdown]
# # THE STUDENT INFO
# ## Student Name: Muhammet Batuhan Doğan
# ## Student ID: 2210765004

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load the dataset
# Replace 'path_to_dataset' with the actual file path
path_to_dataset = 'housing.csv'
housing_df = pd.read_csv(path_to_dataset)
original_df = pd.read_csv(path_to_dataset)

# %% [markdown]
# # We will deal with the famous California Housing Prices dataset from Kaggle. [1]

# %% [markdown]
# # 1. Data Preprocessing (50 Pts)

# %% [markdown]
# # 1.1. Explaratory Data Analysis (10 Pts)
# Check for missing values
#
# Visualize the features with any relevant plots to understand the distribution of data
#
# Visualize the target variable with respect to the features
#
# Visualize the correlation between the features using a heatmap
#
# Comment on any findings

# %%
df_copy1 = housing_df.copy() # for original data.

# %%
df_copy2 = housing_df.copy() #

# %%
df_copy3 = housing_df.copy() #

# %%
df_copy4 = housing_df.copy() #

# %%
df_copy5 = housing_df.copy() #

# %%
df_copy6 = housing_df.copy() #

# %%
# i checked for null values using isnull function.
missing_values = housing_df.isnull().sum()
print(missing_values)
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# Dropping missing values
housing_df.dropna(subset=['total_bedrooms'], inplace=True)

# %% [markdown]
# # I visualized the features with any relevant plots to understand the distribution of data
# I also utilized the describe method after visualizing the features to gain a more detailed understanding.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['longitude'], bins=30, kde=True)
plt.title("Longitude")
plt.show()

housing_df['longitude'].describe()
# Out:
# count    20433.000000
# mean      -119.570689
# std          2.003578
# min       -124.350000
# 25%       -121.800000
# 50%       -118.490000
# 75%       -118.010000
# max       -114.310000
# Name: longitude, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['latitude'], bins=30, kde=True)
plt.title("Latitude")
plt.show()

housing_df['latitude'].describe()
# Out:
# count    20433.000000
# mean        35.633221
# std          2.136348
# min         32.540000
# 25%         33.930000
# 50%         34.260000
# 75%         37.720000
# max         41.950000
# Name: latitude, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['total_rooms'], bins=30, kde=True)
plt.title("Total Rooms")
plt.show()

housing_df['total_rooms'].describe()
# Out:
# count    20433.000000
# mean      2636.504233
# std       2185.269567
# min          2.000000
# 25%       1450.000000
# 50%       2127.000000
# 75%       3143.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['total_bedrooms'], bins=30, kde=True)
plt.title("Total Bedrooms")
plt.show()

housing_df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['population'], bins=30, kde=True)
plt.title("Population")
plt.show()

housing_df['population'].describe()
# Out:
# count    20433.000000
# mean      1424.946949
# std       1133.208490
# min          3.000000
# 25%        787.000000
# 50%       1166.000000
# 75%       1722.000000
# max      35682.000000
# Name: population, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['households'], bins=30, kde=True)
plt.title("Households")
plt.show()

housing_df['households'].describe()
# Out:
# count    20433.000000
# mean       499.433465
# std        382.299226
# min          1.000000
# 25%        280.000000
# 50%        409.000000
# 75%        604.000000
# max       6082.000000
# Name: households, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['median_income'], bins=30, kde=True)
plt.title("Median_income")
plt.show()

housing_df['median_income'].describe()
# Out:
# count    20433.000000
# mean         3.871162
# std          1.899291
# min          0.499900
# 25%          2.563700
# 50%          3.536500
# 75%          4.744000
# max         15.000100
# Name: median_income, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['housing_median_age'], bins=30, kde=True)
plt.title("Housing_median_age")
plt.show()

housing_df['housing_median_age'].describe()
# Out:
# count    20433.000000
# mean        28.633094
# std         12.591805
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['median_house_value'], bins=30, kde=True)
plt.title("Median_house_value")
plt.show()

housing_df['median_house_value'].describe()
# Out:
# count     20433.000000
# mean     206864.413155
# std      115435.667099
# min       14999.000000
# 25%      119500.000000
# 50%      179700.000000
# 75%      264700.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.pie(housing_df['ocean_proximity'].value_counts(), labels=housing_df['ocean_proximity'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Ocean Proximity')
plt.show()

# %% [markdown]
# # I visualized the target variable with respect to the features

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='longitude', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Longitude vs Median House Value')
plt.show()

correlation_coefficient = housing_df['longitude'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# -0.04539821933444482

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='latitude', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Latitude vs Median House Value')
plt.show()

correlation_coefficient = housing_df['latitude'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# -0.14463821157621057

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='housing_median_age', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Housing_median_age vs Median House Value')
plt.show()

correlation_coefficient = housing_df['housing_median_age'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# 0.10643204687615464

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='total_rooms', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Total_rooms vs Median House Value')
plt.show()

correlation_coefficient = housing_df['total_rooms'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# 0.1332941348083227

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='total_bedrooms', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Total_bedrooms vs Median House Value')
plt.show()

correlation_coefficient = housing_df['total_bedrooms'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# 0.049686180247345904

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='population', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Population vs Median House Value')
plt.show()

correlation_coefficient = housing_df['population'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# -0.025299732287442003

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='households', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Households vs Median House Value')
plt.show()

correlation_coefficient = housing_df['households'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# 0.06489354948814169

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='median_income', y='median_house_value', data=housing_df)
plt.title(f'Scatter Plot of Median_income vs Median House Value')
plt.show()

correlation_coefficient = housing_df['median_income'].corr(housing_df['median_house_value'])
correlation_coefficient
# Out:
# 0.6883554753161125

# %% [markdown]
# # I visualized the correlation between the features using a heatmap

# %%
correlation_matrix = housing_df.corr()

# i created a heatmap.
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# # Comment on Explaratory Data Analysis part
#
# I discovered that within the dataset, there were a total of 207 missing values in the 'total_bedrooms' column, which constituted approximately 1% of the total values. I chose to address this issue by dropping those rows, and then proceeded with the updated dataframe.
#
# In the histogram section, I visualized the distribution of features and gained insights into their characteristics. For instance, the longitude and latitude exhibit a bimodal distribution. Total rooms, total bedrooms, population, and households display a right-skewed distribution with long tails, suggesting the presence of extreme values that may impact our data. Median income appears to have a roughly normal distribution but with a right-sided tail. Unlike the tails in the aforementioned features, this tail is not as elongated, prompting me to consider separating it from the other features.
#
# The median age exhibits a wavy distribution with more than three modes, indicating different underlying distributions. As for the median house value, it appears right-skewed, yet there is another mode on the right side. To determine whether it is bimodal or if there are outliers, I will further investigate in the outlier analysis section.
#
#
# In the scatter plot analysis, while some graphs provided clear insights, others were challenging to interpret. To obtain a more accurate understanding, I employed correlation coefficients. Consequently, based on both the visual examination of graphs and correlation coefficients:
#
# Longitude, latitude, and population exhibited very weak negative correlations, almost approaching no correlation.
#
# Median age, total rooms, total bedrooms, and households demonstrated very weak positive correlations, almost akin to no correlation.
#
# However, in the case of Median income, a positive correlation was evident, supported by a correlation coefficient of 0.68.
#
# For the categorical variable 'ocean proximity,' the distribution is as follows:
#
# <1H OCEAN 9136
# INLAND 6551
# NEAR OCEAN 2658
# NEAR BAY 2290
# ISLAND 5
# However, it's worth noting that due to the removal of some values, the pie graph may not accurately represent the presence of the 'ISLAND' category. This suggests a potential loss of information in our analysis.
#
# In the heatmap analysis, I observed a strong positive linear relationship between total rooms, total bedrooms, population, and households. The positive nature of the relationship is indicated by the plus values, and the strength is emphasized by the proximity of the values to 1. It's important to note that correlation does not imply causation; this strong correlation suggests an association but not a causal relationship.
#
# Similarly, for longitude and latitude, there is a strong negative linear relationship, as evidenced by the values close to -1. This implies that as one variable increases, the other tends to decrease.
#
# However, for the remaining features, we cannot confidently assert strong linear relationships as the correlation values are not close to 1 or -1.

# %% [markdown]
# ## 1.2. Outlier Detection (15 Pts)
# * Choose an outlier detection method and apply it to the data.
# * Explain your method and why you choose it.

# %%
# i applied iqr method for total rooms
Q1 = housing_df['total_rooms'].quantile(0.25)
Q3 = housing_df['total_rooms'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

total_rooms_outliers = (housing_df['total_rooms'] < LW) | (housing_df['total_rooms'] > UW)

# %%
# i applied iqr method for total bedrooms
Q1 = housing_df['total_bedrooms'].quantile(0.25)
Q3 = housing_df['total_bedrooms'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

total_bedrooms_outliers = (housing_df['total_bedrooms'] < LW) | (housing_df['total_bedrooms'] > UW)

# %%
# i applied iqr method for population
Q1 = housing_df['population'].quantile(0.25)
Q3 = housing_df['population'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

population_outliers = (housing_df['population'] < LW) | (housing_df['population'] > UW)

# %%
# i applied iqr method for households
Q1 = housing_df['households'].quantile(0.25)
Q3 = housing_df['households'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

households_outliers = (housing_df['households'] < LW) | (housing_df['households'] > UW)

# %%
# i applied iqr method for median income
Q1 = housing_df['median_income'].quantile(0.25)
Q3 = housing_df['median_income'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

median_income_outliers = (housing_df['median_income'] < LW) | (housing_df['median_income'] > UW)

# %%
# i applied iqr method for median house value
Q1 = housing_df['median_house_value'].quantile(0.25)
Q3 = housing_df['median_house_value'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

median_house_value_outliers = (housing_df['median_house_value'] < LW) | (housing_df['median_house_value'] > UW)

# %%
housing_dfa = housing_df.copy()

# %%
# i applied iqr method for longitude
Q1 = housing_df['longitude'].quantile(0.25)
Q3 = housing_df['longitude'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

longitude_outliers = (housing_df['longitude'] < LW) | (housing_df['longitude'] > UW)

# %%
# i applied iqr method for latitude
Q1 = housing_df['latitude'].quantile(0.25)
Q3 = housing_df['latitude'].quantile(0.75)
IQR = Q3 - Q1

LW = Q1 - 1.5 * IQR
UW = Q3 + 1.5 * IQR

latitude_outliers = (housing_df['latitude'] < LW) | (housing_df['latitude'] > UW)

# %%
from scipy.stats import zscore

housing_median_age = housing_df['housing_median_age']

#i  calculated z-scores
z_scores = zscore(housing_median_age)

threshold = 3

outliers_indices = np.where(np.abs(z_scores) > threshold)[0]

# Visualize the outliers
plt.figure(figsize=(10, 6))
plt.scatter(housing_df.index, housing_df['housing_median_age'], c=np.isin(housing_df.index, outliers_indices), cmap='viridis', marker='.')
plt.title('Outlier Detection using Z-Score for Housing Median Age')
plt.xlabel('Data Point Index')
plt.ylabel('Housing Median Age')
plt.show()

print("Indices of Outliers based on Housing Median Age:")
print(outliers_indices)
# Out:
# Indices of Outliers based on Housing Median Age:
# []

# %% [markdown]
# # Comment part for outlier detection
# I choose iqr method for 'total_rooms', 'total_bedrooms', 'population', 'households','median income','median house value', 'longitude', 'latitude' because these features are right skewed and have long tail.Also for these feature mean  and median not so close each other so when this happen we say there may outlier maybe extreme outlier in this case using iqr meaningfull because of its nature it only take into from 25% to 75% data so it is not affect by outlier.
#
# I choose Z-score for 'median house value' because it has close mean and median value then emprical rule in statistic come my mind and i thought using threshold is meaningful for this feature.

# %% [markdown]
# ## 1.3. Outlier Handling (15 Pts)
# Try the following methods to handle outliers, creating checkpoints for each. Additionally, visualize the final data distribution after each method to identify any significant changes
# 1. Keep the dataset as is - take the original checkpoint for baseline comparison.
# 2. Outlier removal
# 3. Mean Imputation (Use Mode imputation for categorical variables)
# 4. Median Imputation (Use Mode imputation for categorical variables)

# %%
def checkpoint(dataframe, filename):
    dataframe.to_csv(f"{filename}.csv", index=False)
    print(f"Checkpoint '{filename}' created.")

# %%
df_copy1 = housing_df.copy() # for original data.

# %%
df_copy1.dropna(subset=['total_bedrooms'], inplace=True)

# %%
checkpoint(df_copy1,'my_original_data')
# Out:
# Checkpoint 'my_original_data' created.

# %%
df_copy2.dropna(subset=['total_bedrooms'], inplace=True)

# %% [markdown]
# # Start point for remove outlier part

# %%
# i removed outliers of total rooms. 
filtered_dataset_total_rooms = df_copy2[~total_rooms_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_total_rooms['total_rooms'], bins=30, kde=True)
plt.title("Total Rooms")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['total_rooms'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_total_rooms['total_rooms'].describe())
# Out:
# Describe of original data:
# count    20433.000000
# mean      2636.504233
# std       2185.269567
# min          2.000000
# 25%       1450.000000
# 50%       2127.000000
# 75%       3143.000000
# max      39320.000000
# Name: total_rooms, dtype: float64
#
# Describe of no outlier original data:
# count    19143.000000
# mean      2221.992791
# std       1148.899417
# min          2.000000
# 25%       1407.000000
# 50%       2036.000000
# 75%       2888.000000
# max       5679.000000
# Name: total_rooms, dtype: float64

# %%
# i removed outliers of total bedrooms. 
filtered_dataset_total_bedrooms = df_copy2[~total_bedrooms_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_total_bedrooms['total_bedrooms'], bins=30, kde=True)
plt.title("Total Bedrooms")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['total_bedrooms'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_total_bedrooms['total_bedrooms'].describe())
# Out:
# Describe of original data:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64
#
# Describe of no outlier original data:
# count    19162.000000
# mean       458.033713
# std        236.731742
# min          1.000000
# 25%        288.000000
# 50%        416.000000
# 75%        595.000000
# max       1173.000000
# Name: total_bedrooms, dtype: float64

# %%
# i removed outliers of population. 
filtered_dataset_population = df_copy2[~population_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_population['population'], bins=30, kde=True)
plt.title("Population")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['population'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_population['population'].describe())
# Out:
# Describe of original data:
# count    20433.000000
# mean      1424.946949
# std       1133.208490
# min          3.000000
# 25%        787.000000
# 50%       1166.000000
# 75%       1722.000000
# max      35682.000000
# Name: population, dtype: float64
#
# Describe of no outlier original data:
# count    19243.000000
# mean      1225.285662
# std        640.043503
# min          3.000000
# 25%        767.000000
# 50%       1121.000000
# 75%       1594.000000
# max       3124.000000
# Name: population, dtype: float64

# %%
# i removed outliers of households. 
filtered_dataset_households = df_copy2[~households_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_households['households'], bins=30, kde=True)
plt.title("Households")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['households'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_households['households'].describe())
# Out:
# Describe of original data:
# count    20433.000000
# mean       499.433465
# std        382.299226
# min          1.000000
# 25%        280.000000
# 50%        409.000000
# 75%        604.000000
# max       6082.000000
# Name: households, dtype: float64
#
# Describe of no outlier original data:
# count    19223.000000
# mean       429.637101
# std        220.930310
# min          1.000000
# 25%        273.000000
# 50%        392.000000
# 75%        557.000000
# max       1090.000000
# Name: households, dtype: float64

# %%
# i removed outliers of  median income. 
filtered_dataset_median_income_outliers = df_copy2[~median_income_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_median_income_outliers['median_income'], bins=30, kde=True)
plt.title("Median Income")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['median_income'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_median_income_outliers['median_income'].describe())
# Out:
# Describe of original data:
# count    20433.000000
# mean         3.871162
# std          1.899291
# min          0.499900
# 25%          2.563700
# 50%          3.536500
# 75%          4.744000
# max         15.000100
# Name: median_income, dtype: float64
#
# Describe of no outlier original data:
# count    19763.000000
# mean         3.658839
# std          1.489592
# min          0.499900
# 25%          2.536900
# 50%          3.472200
# 75%          4.596700
# max          8.014400
# Name: median_income, dtype: float64

# %%
df_copy2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# i removed outliers of  median house value. 
filtered_dataset_median_house_value_outliers = df_copy2[~median_house_value_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_median_house_value_outliers['median_house_value'], bins=30, kde=True)
plt.title("Median House Value")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['median_house_value'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_median_house_value_outliers['median_house_value'].describe())
# Out:
# Describe of original data:
# count     20433.000000
# mean     206864.413155
# std      115435.667099
# min       14999.000000
# 25%      119500.000000
# 50%      179700.000000
# 75%      264700.000000
# max      500001.000000
# Name: median_house_value, dtype: float64
#
# Describe of no outlier original data:
# count     19369.000000
# mean     190802.064949
# std       95404.934086
# min       14999.000000
# 25%      116100.000000
# 50%      173200.000000
# 75%      246400.000000
# max      482200.000000
# Name: median_house_value, dtype: float64

# %%
longitude_outliers
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: longitude, Length: 20433, dtype: bool

# %%
# i removed outliers of  median house value. 
filtered_dataset_longitude_outliers = df_copy2[~longitude_outliers]

# i visualized no outlier data.
plt.figure(figsize=(8, 6))
sns.histplot(filtered_dataset_longitude_outliers['longitude'], bins=30, kde=True)
plt.title("Longitude")
plt.show()

# to compare outlier data and no outlier data.
print('Describe of original data:')
print(df_copy2['longitude'].describe())
print()
print('Describe of no outlier original data:')
print(filtered_dataset_longitude_outliers['longitude'].describe())
# Out:
# Describe of original data:
# count    20433.000000
# mean      -119.570689
# std          2.003578
# min       -124.350000
# 25%       -121.800000
# 50%       -118.490000
# 75%       -118.010000
# max       -114.310000
# Name: longitude, dtype: float64
#
# Describe of no outlier original data:
# count    20433.000000
# mean      -119.570689
# std          2.003578
# min       -124.350000
# 25%       -121.800000
# 50%       -118.490000
# 75%       -118.010000
# max       -114.310000
# Name: longitude, dtype: float64

# %% [markdown]
# For longitude we see there is no outlier for my method. This is same also langitude so i do not add latitude graphs.
# In addition for Housing Median age there is no outlier for this i also not add this graph. Because it is gonna same.

# %% [markdown]
# # Final point for remove outlier part

# %% [markdown]
# # Start point for mean imputation

# %%
column_name = 'total_bedrooms'


mean_value = df_copy3[column_name].mean()

# Impute missing values with the mean
df_copy3[column_name].fillna(mean_value, inplace=True)

# %%
checkpoint(df_copy3, 'checkpoint_mean_imputed')
# Out:
# Checkpoint 'checkpoint_mean_imputed' created.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['total_bedrooms'], bins=30, kde=True)
plt.title("Total Bedrooms")
plt.show()

housing_df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_copy3['total_bedrooms'], bins=30, kde=True)
plt.title("Total Bedrooms")
plt.show()

df_copy3['total_bedrooms'].describe()
# Out:
# count    20640.000000
# mean       537.870553
# std        419.266592
# min          1.000000
# 25%        297.000000
# 50%        438.000000
# 75%        643.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %% [markdown]
# In this part i did mean imputation for only total_rooms because it has only missing value. We do not need for other features because these feature do not have missing value. And we see that after mean imputation there is no change mean value for original data and imputing data because we change missing value with mean value

# %% [markdown]
# # Final point for mean imputation

# %% [markdown]
# # Start point for median imputation

# %%
column_name = 'total_bedrooms'


median_value = df_copy4[column_name].median()

# Impute missing values with the median
df_copy4[column_name].fillna(median_value, inplace=True)

# %%
checkpoint(df_copy4, 'checkpoint_median_imputed')
# Out:
# Checkpoint 'checkpoint_median_imputed' created.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['total_bedrooms'], bins=30, kde=True)
plt.title("Total Bedrooms")
plt.show()

housing_df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_copy4['total_bedrooms'], bins=30, kde=True)
plt.title("Total Bedrooms")
plt.show()

df_copy4['total_bedrooms'].describe()
# Out:
# count    20640.000000
# mean       536.838857
# std        419.391878
# min          1.000000
# 25%        297.000000
# 50%        435.000000
# 75%        643.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %% [markdown]
# In this part i did median imputation for only total_rooms because it has only missing value. We do not need for other features because these feature do not have missing value.
# After median imputation we see mean decrease a bit because our original data has right skewed distribution so median < mean and we aspect mean gonna decrease after impuation and we got it. So our imputation do not have problem.

# %% [markdown]
# # Final point median imputation

# %% [markdown]
# ## 1.4. Encode the Ordinal Features with Ordinal Encoding (2 Pts)

# %%
# i did encoding
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder(categories=[['<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'NEAR BAY', 'ISLAND']])
df_copy5['ocean_proximity_encoded'] = ordinal_encoder.fit_transform(df_copy5[['ocean_proximity']])

# %%
# i drop not encoding ocean proximity
df_copy5.drop('ocean_proximity', axis=1, inplace=True)

# %%
df_copy5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   longitude                20640 non-null  float64
#  1   latitude                 20640 non-null  float64
#  2   housing_median_age       20640 non-null  float64
#  3   total_rooms              20640 non-null  float64
#  4   total_bedrooms           20433 non-null  float64
#  5   population               20640 non-null  float64
#  6   households               20640 non-null  float64
#  7   median_income            20640 non-null  float64
#  8   median_house_value       20640 non-null  float64
#  9   ocean_proximity_encoded  20640 non-null  float64
# dtypes: float64(10)
# memory usage: 1.6 MB

# %% [markdown]
# ## 1.5. Manually shuffle the dataset and split it into training (70%) and testing (30%) sets. Write your own code for shuffling and splitting, avoiding the use of pre-defined functions like train_test_split." (8 Pts)
#
# You  cannot use scikit-learn's shuffle.

# %%
# i shuffled the dataset
shuffled_indices = np.random.permutation(len(df_copy5))
df_copy5_shuffled = df_copy5.iloc[shuffled_indices].reset_index(drop=True)

# i splitted into training (70%) and testing (30%) sets
total_samples = len(df_copy5_shuffled)
train_size = int(0.7 * total_samples)

training_set = df_copy5_shuffled.iloc[:train_size]
testing_set = df_copy5_shuffled.iloc[train_size:]

X_train = training_set.drop('median_house_value', axis=1)
y_train = training_set['median_house_value']

X_test = testing_set.drop('median_house_value', axis=1)
y_test = testing_set['median_house_value']

# %% [markdown]
# # 2. REGRESSION (50 Pts)
# * Target value: median_house_value
# * Predictors: The rest

# %% [markdown]
# ## 2.1. kNN Regression (20 Pts)
# * For each version of the dataset (original, outlier-removed, mean-imputed, median-imputed), execute the following steps:"
#     * Split the data into train and test sets
#     * Create an instance of kNN with a number of neighbors between 1-30, then fit kNN regression model to train data. Predict the test set and calculate the MSE value for each k. Plot the MSE vs k curve to decide on the optimal k. Additionally, report the R-squared value for the optimal k.
# * Compare the MSE values for each dataset and comment on the results. Which dataset gives the best result? Why do you think that is?
#
# You can use scikit-learn's KNeighborsRegressor.

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

original_dataset = pd.read_csv('my_original_data.csv')

target_variable = 'median_house_value'

# Function to perform kNN Regression and plot MSE vs k curve
def knn_regression_and_plot_mse(X, y, dataset_name):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Initialize variables
    mse_values = []
    r2_values = []

    k_values = range(1, 31)

    # Iterate over different k values
    for k in k_values:
        knn_regressor = KNeighborsRegressor(n_neighbors=k)

        knn_regressor.fit(X_train, y_train)

        y_pred = knn_regressor.predict(X_test)

        # i calculated MSE and R-squared values
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        mse_values.append(mse)
        r2_values.append(r2)

    optimal_k = k_values[np.argmin(mse_values)]

    plt.figure(figsize=(10, 6))
    plt.plot(k_values, mse_values, marker='o')
    plt.title(f'MSE vs k for {dataset_name} Dataset')
    plt.xlabel('Number of Neighbors (k)')
    plt.ylabel('Mean Squared Error (MSE)')
    plt.grid(True)
    plt.show()

    print(f"Optimal k for {dataset_name} dataset: {optimal_k}")
    print(f"MSE for optimal k: {mse_values[optimal_k - 1]}")
    print(f"R-squared value for optimal k: {r2_values[optimal_k - 1]}")


X_original = housing_df[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']]

X_outlier_removed = filtered_dataset_total_rooms[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value' ]]
X_mean_imputed = df_copy3[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']]
X_median_imputed = df_copy4[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']]


y_original = housing_df['median_house_value']
y_outlier_removed = filtered_dataset_total_rooms['median_house_value']
y_mean_imputed = df_copy3['median_house_value']
y_median_imputed = df_copy4['median_house_value']




# For the original dataset
knn_regression_and_plot_mse(X_original, y_original, 'Original')

# For the outlier-removed dataset
knn_regression_and_plot_mse(X_outlier_removed, y_outlier_removed, 'Outlier Removed')

# For the mean-imputed dataset
knn_regression_and_plot_mse(X_mean_imputed, y_mean_imputed, 'Mean Imputed')

# For the median-imputed dataset
knn_regression_and_plot_mse(X_median_imputed, y_median_imputed, 'Median Imputed')
# Out:
# Optimal k for Original dataset: 5
# MSE for optimal k: 71734.87528221858
# R-squared value for optimal k: 0.9999946189153971
# Optimal k for Outlier Removed dataset: 8
# MSE for optimal k: 26203.84337998433
# R-squared value for optimal k: 0.9999979542094491
# Optimal k for Mean Imputed dataset: 7
# MSE for optimal k: 87102.58012972624
# R-squared value for optimal k: 0.9999933638157332
# Optimal k for Median Imputed dataset: 7
# MSE for optimal k: 87091.76960396554
# R-squared value for optimal k: 0.9999933646393672

# %% [markdown]
# # Comment Part

# %% [markdown]
#  R-squared values are very close to 1 so we may say kNN regression models are fitting the data extremely well also i say there is overfitting.
#
# Optimal k values different for each dataset we expect this because the number of neighbors that minimizes MSE may differ depending on the dataset.
#
# Outlier Removed dataset has lowest MSE, so we say that the removing outliers had a positive affect on the model's performance.
#
# Mean Imputed and Median Imputed datasets have similar MSE values, so choice of imputation method (mean or median) did not have a significant impact on my model performance.

# %% [markdown]
# ## 2.2. Linear Regression (20 Pts)
# * For each version of the dataset (original, outlier removal, mean imputation, median imputation), do the following:
#     * Split the data into train and test sets
#     * Fit a linear regression model to train data. Predict the test set and calculate the MSE value.

# %%
from sklearn.linear_model import LinearRegression

def linear_regression_and_plot(X, y, dataset_name):
    # i splitted the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    linear_regressor = LinearRegression()

    linear_regressor.fit(X_train, y_train)

    y_pred = linear_regressor.predict(X_test)

    # Calculate MSE
    mse = mean_squared_error(y_test, y_pred)

    # Plot the actual vs. predicted values
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, color='blue')
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2, label='Ideal Prediction')
    plt.title(f'Linear Regression for {dataset_name} Dataset')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.legend()
    plt.show()

    # Print the MSE value
    print(f"MSE for {dataset_name} dataset: {mse}")

# Call the function for each version of the dataset
linear_regression_and_plot(X_original, y_original, 'Original')
linear_regression_and_plot(X_outlier_removed, y_outlier_removed, 'Outlier Removed')
linear_regression_and_plot(X_mean_imputed, y_mean_imputed, 'Mean Imputed')
linear_regression_and_plot(X_median_imputed, y_median_imputed, 'Median Imputed')
# Out:
# MSE for Original dataset: 1.2351130034396788e-20
# MSE for Outlier Removed dataset: 4.154128402481316e-21
# MSE for Mean Imputed dataset: 3.2525938639443006e-21
# MSE for Median Imputed dataset: 3.256843050140051e-21

# %% [markdown]
# ## 2.3. Compare the Regression Methods (10 Pts)
#
# Compare and contrast the performance of kNN and Linear Regression models across the different dataset versions (those attained in 1.3.). Discuss the strengths and limitations of each model based on your results

# %% [markdown]
# For my  knn model i say these things
# If our model is perfect then R^2=1 my R^2 values are so close to 1 so i almost say my model is almost perfect for goodness of fit of a model.
# For MSE values i say that original data, mean imputed data and median imputed data have around 87k Mse but Outlier removal data has 26k Mse so we say that removing outlier improve our model's performance.
# In addition  k values different for each dataset they are close to each other almost they are different because the number of neighbors that minimizes MSE may differ depending on the dataset.
#
# For Linear Regression my  MSE values for every dataset versions very low this suggest that the linear regression models are fitting the data extremely well, almost perfectly.

# %% [markdown]
# # PLAGIARISM POLICY
#
# In the interest of maintaining a fair and honest academic environment, this course strictly adheres to a zero-tolerance policy regarding plagiarism.
# Accordingly, all assignments must reflect individual effort and understanding. While abstract discussions with peers about concepts are encouraged, sharing or copying specific solutions, code, or pseudocode is not permitted and will be treated as plagiarism. This policy includes work sourced from the internet, publications, and AI tools like ChatGPT and GitHub Copilot. **MAKE USE OF THEM RESPONSIBLY**. That is, you can utilize them to enhance understanding and support your original work, **not to replace it**. Submitting work that is not entirely your own creation will be regarded as a violation of academic integrity. It is vital to use all resources, including AI, in a manner that supports your educational development without compromising the principles of academic honesty.
#
# If in doubt, do not hesitate to seek guidance from the course staff - we are here to help, with an aim to foster a learning environment based on trust, respect, and responsibility.

# %% [markdown]
# # REFERENCES
# [1] Nugent, C. (n.d.). California Housing Prices [Data set]. Kaggle. Retrieved from https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %% [markdown]
# # ACKNOWLEDGMENTS
#
# In certain sections of this study, I utilized the AI tool ChatGPT, AIN212 course slides, AIN214 lab materials,Piazza
# and Google translate to enhance my understanding.
